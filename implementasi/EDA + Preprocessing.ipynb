# %% [markdown]
# <h3>Read Dataset</h3>

# %%
import pandas as pd
dataset_1 = pd.read_csv('data/articles_data.csv') 
dataset_2 = pd.read_csv('data/wiki_movie_plots_deduped.csv')
# Out:
# C:\Users\Indah\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Indah\anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\Indah\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
dataset_1.head()
# Out:
#    Unnamed: 0           source_id         source_name              author  \
# 0           0             reuters             Reuters   Reuters Editorial
# 1           1     the-irish-times     The Irish Times  Eoin Burke-Kennedy
# 2           2     the-irish-times     The Irish Times   Deirdre McQuillan
# 3           3  al-jazeera-english  Al Jazeera English          Al Jazeera
# 4           4            bbc-news            BBC News            BBC News
#
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 4  UK government lawyer says proroguing parliamen...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# ...

# %%
dataset_2.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# ...

# %%
# view more information about the dataset_1 using describe method
dataset_1.describe()
# Out:
#          Unnamed: 0   top_article  engagement_reaction_count  \
# count  10437.000000  10435.000000               10319.000000
# mean    5218.000000      0.122089                 381.395290
# std     3013.046714      0.327404                4433.344792
# min        0.000000      0.000000                   0.000000
# 25%     2609.000000      0.000000                   0.000000
# 50%     5218.000000      0.000000                   1.000000
# 75%     7827.000000      0.000000                  43.000000
# max    10436.000000      1.000000              354132.000000
#
#        engagement_comment_count  engagement_share_count  \
# count              10319.000000            10319.000000
# mean                 124.032949              196.236263
# std                  965.351188             1020.680229
# min                    0.000000                0.000000
# 25%                    0.000000                1.000000
# 50%                    0.000000                8.000000
# ...

# %%
# view more information about the dataset_2 using describe method
dataset_2.describe()
# Out:
#        Release Year
# count  34886.000000
# mean    1981.314252
# std       27.815174
# min     1901.000000
# 25%     1957.000000
# 50%     1988.000000
# 75%     2007.000000
# max     2017.000000

# %%
#view more info on dataset_1
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10437 entries, 0 to 10436
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       10437 non-null  int64
#  1   source_id                        10437 non-null  object
#  2   source_name                      10437 non-null  object
#  3   author                           9417 non-null   object
#  4   title                            10435 non-null  object
#  5   description                      10413 non-null  object
#  6   url                              10436 non-null  object
#  7   url_to_image                     9781 non-null   object
#  8   published_at                     10436 non-null  object
#  9   content                          9145 non-null   object
#  10  top_article                      10435 non-null  float64
#  11  engagement_reaction_count        10319 non-null  float64
# ...

# %%
#view more info on dataset_2
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34886 non-null  int64
#  1   Title             34886 non-null  object
#  2   Origin/Ethnicity  34886 non-null  object
#  3   Director          34886 non-null  object
#  4   Cast              33464 non-null  object
#  5   Genre             34886 non-null  object
#  6   Wiki Page         34886 non-null  object
#  7   Plot              34886 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
print("Dataset size:", dataset_1.shape)
print("Dataset columns:", dataset_1.columns)
# Out:
# Dataset size: (10437, 15)
# Dataset columns: Index(['Unnamed: 0', 'source_id', 'source_name', 'author', 'title',
#        'description', 'url', 'url_to_image', 'published_at', 'content',
#        'top_article', 'engagement_reaction_count', 'engagement_comment_count',
#        'engagement_share_count', 'engagement_comment_plugin_count'],
#       dtype='object')

# %%
print("Dataset size:", dataset_2.shape)
print("Dataset columns:", dataset_2.columns)
# Out:
# Dataset size: (34886, 8)
# Dataset columns: Index(['Release Year', 'Title', 'Origin/Ethnicity', 'Director', 'Cast',
#        'Genre', 'Wiki Page', 'Plot'],
#       dtype='object')

# %% [markdown]
# <h3>Drop Column</h3>

# %%
dataset_1.drop(['Unnamed: 0', 'source_id', 'source_name', 'author','url', 'url_to_image', 'published_at',
       'top_article', 'engagement_reaction_count', 'engagement_comment_count',
       'engagement_share_count', 'engagement_comment_plugin_count'], inplace=True, axis=1)

# %%
dataset_1.head()
# Out:
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 4  UK government lawyer says proroguing parliamen...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# 2  Autumn-winter collection features designer’s g...
# 3  Han is the first North Korean player in the Se...
# 4  The UK government's lawyer, David Johnston arg...
#
#                                              content
# 0  WASHINGTON (Reuters) - The National Transporta...
# 1  The States jobless rate fell to 5.2 per cent l...
# 2  Louise Kennedy is showing off her autumn-winte...
# 3  Han Kwang Song, the first North Korean footbal...
# 4                                                NaN

# %%
print("Dataset size:", dataset_1.shape)
print("Dataset columns:", dataset_1.columns)
# Out:
# Dataset size: (10437, 3)
# Dataset columns: Index(['title', 'description', 'content'], dtype='object')

# %%
dataset_2.drop(['Release Year', 'Origin/Ethnicity', 'Director', 'Cast', 'Genre', 'Wiki Page'], inplace=True, axis=1)

# %%
dataset_2.head()
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
print("Dataset size:", dataset_2.shape)
print("Dataset columns:", dataset_2.columns)
# Out:
# Dataset size: (34886, 2)
# Dataset columns: Index(['Title', 'Plot'], dtype='object')

# %% [markdown]
# <h3>Cek nilai null</h3>

# %%
print("Cek Missing Value:\n" ,dataset_1.isnull().any())
dataset_1.isnull().sum()
# Out:
# Cek Missing Value:
#  title          True
# description    True
# content        True
# dtype: bool
# title             2
# description      24
# content        1292
# dtype: int64

# %%
print("Cek Missing Value:\n" ,dataset_2.isnull().any())
dataset_2.isnull().sum()
# Out:
# Cek Missing Value:
#  Title    False
# Plot     False
# dtype: bool
# Title    0
# Plot     0
# dtype: int64

# %% [markdown]
# <h3> Drop Missing Value</h3>

# %%
dataset_1 = dataset_1[dataset_1['title'].notna()]
dataset_1 = dataset_1[dataset_1['description'].notna()]
dataset_1 = dataset_1[dataset_1['content'].notna()]

# %%
print("Cek Missing Value:\n" ,dataset_1.isnull().any())
dataset_1.isnull().sum()
# Out:
# Cek Missing Value:
#  title          False
# description    False
# content        False
# dtype: bool
# title          0
# description    0
# content        0
# dtype: int64

# %%
print("Dataset size:", dataset_1.shape)
print("Dataset columns:", dataset_1.columns)
# Out:
# Dataset size: (9137, 3)
# Dataset columns: Index(['title', 'description', 'content'], dtype='object')

# %%
dataset_1['length'] =dataset_1['title'].apply(len)

# %%
# view first 5 messages with length
dataset_1.head()
# Out:
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 5  'This Tender Land' is an affecting story about...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# 2  Autumn-winter collection features designer’s g...
# 3  Han is the first North Korean player in the Se...
# 5  "This Tender Land" by William Kent Krueger is ...
#
#                                              content  length
# 0  WASHINGTON (Reuters) - The National Transporta...      58
# 1  The States jobless rate fell to 5.2 per cent l...      44
# 2  Louise Kennedy is showing off her autumn-winte...      76
# 3  Han Kwang Song, the first North Korean footbal...      57
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
Tweet = str(dataset_1.title.values)

wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black'
).generate(Tweet)

fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')

plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
# The length of the headline_text
lens = dataset_1.title.str.len()
print("Rata-rata panjang title:\n", lens.mean())
print("Standar Deviasi title:\n", lens.std())
print("Panjang minimal title:\n", lens.min())
print("Panjang maksimal title:\n", lens.max())

lens.hist();
# Out:
# Rata-rata panjang title:
#  67.58761081317719
# Standar Deviasi title:
#  23.775645471670774
# Panjang minimal title:
#  8
# Panjang maksimal title:
#  250

# %%
# The length of the description
lens = dataset_1.description.str.len()
print("Rata-rata panjang description:\n", lens.mean())
print("Standar Deviasi description:\n", lens.std())
print("Panjang minimal description:\n", lens.min())
print("Panjang maksimal description:\n", lens.max())

lens.hist();
# Out:
# Rata-rata panjang description:
#  155.03797745430666
# Standar Deviasi description:
#  64.90859447900442
# Panjang minimal description:
#  18
# Panjang maksimal description:
#  260

# %%
# The length of the content
lens = dataset_1.content.str.len()
print("Rata-rata panjang content:\n", lens.mean())
print("Standar Deviasi content:\n", lens.std())
print("Panjang minimal content:\n", lens.min())
print("Panjang maksimal content:\n", lens.max())

lens.hist();
# Out:
# Rata-rata panjang content:
#  265.92590565831233
# Standar Deviasi content:
#  34.57685296178759
# Panjang minimal content:
#  26
# Panjang maksimal content:
#  275

# %%
# The length of the Title in Dataset 2
lens = dataset_2.Title.str.len()
print("Rata-rata panjang title:\n", lens.mean())
print("Standar Deviasi title:\n", lens.std())
print("Panjang minimal title:\n", lens.min())
print("Panjang maksimal title:\n", lens.max())

lens.hist();
# Out:
# Rata-rata panjang title:
#  15.540073381872384
# Standar Deviasi title:
#  8.252638838420097
# Panjang minimal title:
#  1
# Panjang maksimal title:
#  111

# %%
# The length of the plot
lens = dataset_2.Plot.str.len()
print("Rata-rata panjang plot:\n", lens.mean())
print("Standar Deviasi plot:\n", lens.std())
print("Panjang minimal plot:\n", lens.min())
print("Panjang maksimal plot:\n", lens.max())

lens.hist();
# Out:
# Rata-rata panjang plot:
#  2165.0345410766495
# Standar Deviasi plot:
#  1817.3252471111373
# Panjang minimal plot:
#  15
# Panjang maksimal plot:
#  36773

# %% [markdown]
# <h3> Data Preprocessing </h3>

# %%
# !pip install tokenization

# %%
# Impor library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from wordcloud import WordCloud
from nltk.corpus import stopwords
import tokenization
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Indah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Indah\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# <h4> Remove Duplicate - Dataset 1</h4>

# %%
# Menampilkan data duplikat dari dataset 1
data_duplicates = dataset_1[dataset_1.duplicated(subset=['title','description','content'], keep=False)]
print (data_duplicates)
# Out:
#                                                    title  \
# 0      NTSB says Autopilot engaged in 2018 California...
# 9      Boris Johnson to meet Leo Varadkar in Dublin o...
# 24     Trial of actor Cuba Gooding Jr in groping case...
# 43     U.S. edge Turkey, Canada eliminated from World...
# 47      Phones Buzz in Class—With Texts From Mom and Dad
# ...                                                  ...
# 10336    Zverev and Tsitsipas roll into Beijing quarters
# 10366  Canada opposition leader says he is 'pro-life'...
# 10387  The Apprentice review: Which is worse, Donald ...
# 10390  Coal giant Murray Energy in debt talks after m...
# 10418    Zverev and Tsitsipas roll into Beijing quarters
#
#                                              description  \
# 0      The National Transportation Safety Board said ...
# 9      UK prime minister will meet Taoiseach for talk...
# 24     Judge Herbert Moses of the Manhattan Supreme C...
# ...

# %%
# Menghapus data duplikat
dataset_1 = dataset_1.drop_duplicates()
dataset_1.head()
# Out:
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 5  'This Tender Land' is an affecting story about...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# 2  Autumn-winter collection features designer’s g...
# 3  Han is the first North Korean player in the Se...
# 5  "This Tender Land" by William Kent Krueger is ...
#
#                                              content  length
# 0  WASHINGTON (Reuters) - The National Transporta...      58
# 1  The States jobless rate fell to 5.2 per cent l...      44
# 2  Louise Kennedy is showing off her autumn-winte...      76
# 3  Han Kwang Song, the first North Korean footbal...      57
# ...

# %%
# Menggabungkan atribut title, description, dan content menjadi atribut article
dataset_1["article"] = dataset_1["title"] + dataset_1["description"] + dataset_1["content"]

# %%
dataset_1['length'] =dataset_1['article'].apply(len)
dataset_1.head()
# Out:
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 5  'This Tender Land' is an affecting story about...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# 2  Autumn-winter collection features designer’s g...
# 3  Han is the first North Korean player in the Se...
# 5  "This Tender Land" by William Kent Krueger is ...
#
#                                              content  length  \
# 0  WASHINGTON (Reuters) - The National Transporta...     578
# 1  The States jobless rate fell to 5.2 per cent l...     386
# 2  Louise Kennedy is showing off her autumn-winte...     431
# 3  Han Kwang Song, the first North Korean footbal...     445
# ...

# %% [markdown]
# <h4> Remove Duplicate - Dataset 2</h4>

# %%
# Menampilkan data duplikat dari dataset 1
data_duplicates = dataset_2[dataset_2.duplicated(subset=['Title','Plot'], keep=False)]
print (data_duplicates)
# Out:
#                             Title  \
# 149    The Other Side of the Door
# 189               Wild and Woolly
# 227        Nine-Tenths of the Law
# 286        Nine-Tenths of the Law
# 310           Among Those Present
# ...                           ...
# 34434                  Cyborg She
# 34561               I Am the King
# 34582                       B-E-D
# 34703                       B-E-D
# 34749         Bad Guys Always Die
#
#                                                     Plot
# 149    Sets in the 19th century, the plot centered on...
# 189    As described in a film magazine review,[1] Jef...
# 227    As described in a film magazine,[1] Jules Lene...
# 286    As described in a film magazine,[1] Jules Lene...
# 310    Mrs. O'Brien (Herring) is eager to be accepted...
# ...                                                  ...
# 34434  It is 22 November 2007. Jiro Kitamura (Keisuke...
# 34561  When his older brothers Yangnyeong and Hyoryeo...
# ...

# %%
# Menghapus data duplikat
dataset_2 = dataset_2.drop_duplicates()
dataset_2.head()
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
# Menggabungkan atribut title dan Plot menjadi atribut article
dataset_2["Movie"] = dataset_2["Title"] + dataset_2["Plot"]

# %%
dataset_2['length'] =dataset_2['Movie'].apply(len)
dataset_2.head()
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                                                Movie  length
# 0  Kansas Saloon SmashersA bartender is working a...     522
# 1  Love by the Light of the MoonThe moon, painted...     466
# 2  The Martyred PresidentsThe film, just over a m...     459
# 3  Terrible Teddy, the Grizzly KingLasting just 6...     922
# 4  Jack and the BeanstalkThe earliest known adapt...     754

# %% [markdown]
# <h3> Data Preprocessing </h3>

# %%
import nltk
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

# %%
def preprocess_text(text):
    """ Apply any preprocessing methods"""
    text = str(text).lower()  # Lowercase words
    text = re.sub(r"\[(.*?)\]", "", text)  # Remove [+XYZ chars] in content
    text = re.sub(r"\s+", " ", text)  # Remove multiple spaces in content
    text = re.sub(r"\w+…|…", "", text)  # Remove ellipsis (and last word)
    text = re.sub(r"(?<=\w)-(?=\w)", " ", text)  # Replace dash between words
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)  # Remove punctuation

    tokens = nltk.word_tokenize(text)  # Get tokens from text
    tokens = [t for t in tokens if not t in stopwords]  # Remove stopwords
    tokens = ["" if t.isdigit() else t for t in tokens]  # Remove digits
    tokens = [t for t in tokens if len(t) > 1]  # Remove short tokens
    return tokens

#Dataset 1
dataset_1["article"] = dataset_1.title.apply(preprocess_text)

#Dataset 2
dataset_2["Movie"] = dataset_2.Plot.apply(preprocess_text)

# %%
dataset_1.head()
# Out:
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 5  'This Tender Land' is an affecting story about...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# 2  Autumn-winter collection features designer’s g...
# 3  Han is the first North Korean player in the Se...
# 5  "This Tender Land" by William Kent Krueger is ...
#
#                                              content  length  \
# 0  WASHINGTON (Reuters) - The National Transporta...     578
# 1  The States jobless rate fell to 5.2 per cent l...     386
# 2  Louise Kennedy is showing off her autumn-winte...     431
# 3  Han Kwang Song, the first North Korean footbal...     445
# ...

# %%
dataset_2.head()
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                                                Movie  length
# 0  [bartender, working, saloon, serving, drinks, ...     522
# 1  [moon, painted, smiling, face, hangs, park, ni...     466
# 2  [film, minute, long, composed, two, shots, fir...     459
# 3  [lasting, seconds, consisting, two, shots, fir...     922
# 4  [earliest, known, adaptation, classic, fairyta...     754

# %%
# Ekspor data hasil dari preprocessing
dataset_1.to_csv( "data/dataset1_preprocessing.csv", index=False, encoding='utf-8-sig')
dataset_2.to_csv( "data/dataset2_preprocessing.csv", index=False, encoding='utf-8-sig')
